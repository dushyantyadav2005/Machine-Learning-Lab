# %%
import pandas as pd
import numpy as np
from math import log2
import matplotlib.pyplot as plt

# %%
def calculate_entropy_from_counts(counts):
    """Entropy given a list of counts."""
    total = sum(counts)
    probs = [c/total for c in counts if c > 0]  
    return -sum(p * log2(p) for p in probs)


def entropy_categorical(series):
    """Entropy for categorical column."""
    counts = series.value_counts().tolist()
    return calculate_entropy_from_counts(counts)


def entropy_numerical(series, bins=10):
    """Entropy for numerical column (using binning)."""
    counts, _ = np.histogram(series.dropna(), bins=bins)
    return calculate_entropy_from_counts(counts)

# %%
df = pd.read_csv("Housing.csv")

# %%
col_entropies = {}

for col in df.columns:
    if df[col].dtype == "object" or df[col].dtype.name == "category":
        col_entropies[col] = entropy_categorical(df[col])
    else:
        col_entropies[col] = entropy_numerical(df[col])

col_entropies
# Out:
# {'price': np.float64(2.5584120118580436),
#  'area': np.float64(2.4165782102155973),
#  'bedrooms': np.float64(1.5783764246200245),
#  'bathrooms': np.float64(0.9447864125469403),
#  'stories': np.float64(1.6013354416692476),
#  'mainroad': 0.5875926904926543,
#  'guestroom': 0.6756416842992281,
#  'basement': 0.9344770602437216,
#  'hotwaterheating': 0.26859376366582177,
#  'airconditioning': 0.8995281870698584,
#  'parking': np.float64(1.5476148578504698),
#  'prefarea': 0.7863917038359864,
#  'furnishingstatus': 1.557256126637955}

# %%
plt.figure(figsize=(8,5))
plt.bar(col_entropies.keys(), col_entropies.values(), color="skyblue", edgecolor="black")
plt.ylabel("Entropy")
plt.title("Entropy per Column")
plt.xticks(rotation=45)
plt.show()

# %%
df1=pd.read_csv("advertising.csv")

# %%
col_entropies = {}

for col in df1.columns:
    if df1[col].dtype == "object" or df1[col].dtype.name == "category":
        col_entropies[col] = entropy_categorical(df1[col])
    else:
        col_entropies[col] = entropy_numerical(df1[col])


col_entropies
# Out:
# {'TV': np.float64(3.2985207460435655),
#  'Radio': np.float64(3.2895809469720865),
#  'Newspaper': np.float64(2.7522029952412814),
#  'Sales': np.float64(3.053043355558367)}

# %%
plt.figure(figsize=(8,5))
plt.bar(col_entropies.keys(), col_entropies.values(), color="skyblue", edgecolor="black")
plt.ylabel("Entropy")
plt.title("Entropy per Column")
plt.xticks(rotation=45)
plt.show()

# %%
df1=pd.read_csv("faa_ai_prelim.csv")

# %%
col_entropies = {}

for col in df1.columns:
    if df1[col].dtype == "object" or df1[col].dtype.name == "category":
        col_entropies[col] = entropy_categorical(df1[col])
    else:
        col_entropies[col] = entropy_numerical(df1[col])


col_entropies
# Out:
# {'UPDATED': 0.22432696034508792,
#  'ENTRY_DATE': 2.789723011780073,
#  'EVENT_LCL_DATE': 3.850246512101895,
#  'EVENT_LCL_TIME': 6.197269702405196,
#  'LOC_CITY_NAME': 6.2786538891782495,
#  'LOC_STATE_NAME': 4.332993716635016,
#  'LOC_CNTRY_NAME': -0.0,
#  'RMK_TEXT': 6.326846660262587,
#  'EVENT_TYPE_DESC': 0.9100534290139191,
#  'FSDO_DESC': 5.205401664465727,
#  'REGIST_NBR': 6.3750394313469245,
#  'FLT_NBR': 2.584962500721156,
#  'ACFT_OPRTR': 2.521640636343318,
#  'ACFT_MAKE_NAME': 3.8937942899734126,
#  'ACFT_MODEL_NAME': 5.56290321636722,
#  'ACFT_MISSING_FLAG': 0,
#  'ACFT_DMG_DESC': 1.8199400077559358,
#  'FLT_ACTIVITY': 2.038159681645953,
#  'FLT_PHASE': 1.8600270622995048,
#  'FAR_PART': np.float64(-0.0),
#  'MAX_INJ_LVL': 1.8474201200521745,
#  'FATAL_FLAG': -0.0,
#  'FLT_CRW_INJ_NONE': np.float64(0.6985429667217483),
#  'FLT_CRW_INJ_MINOR': np.float64(0.9182958340544896),
#  'FLT_CRW_INJ_SERIOUS': np.float64(-0.0),
#  'FLT_CRW_INJ_FATAL': np.float64(1.0),
#  'FLT_CRW_INJ_UNK': 0,
#  'CBN_CRW_INJ_NONE': 0,
#  'CBN_CRW_INJ_MINOR': 0,
#  'CBN_CRW_INJ_SERIOUS': 0,
#  'CBN_CRW_INJ_FATAL': 0,
#  'CBN_CRW_INJ_UNK': np.float64(-0.0),
#  'PAX_INJ_NONE': np.float64(1.5197284615795614),
#  'PAX_INJ_MINOR': np.float64(-0.0),
#  'PAX_INJ_SERIOUS': np.float64(-0.0),
#  'PAX_INJ_FATAL': np.float64(-0.0),
#  'PAX_INJ_UNK': 0,
#  'GRND_INJ_NONE': 0,
#  'GRND_INJ_MINOR': 0,
#  'GRND_INJ_SERIOUS': 0,
#  'GRND_INJ_FATAL': 0,
#  'GRND_INJ_UNK': np.float64(-0.0)}

# %%
plt.figure(figsize=(8,5))
plt.bar(col_entropies.keys(), col_entropies.values(), color="skyblue", edgecolor="black")
plt.ylabel("Entropy")
plt.title("Entropy per Column")
plt.xticks(rotation=45)
plt.show()
